# %%
import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
df = pd.read_json("Sarcasm_Headlines_Dataset.json", lines=True)

# %%
df.shape
# Out:
# (26709, 3)

# %%
df.head()
# Out:
#                                         article_link  \
# 0  https://www.huffingtonpost.com/entry/versace-b...
# 1  https://www.huffingtonpost.com/entry/roseanne-...
# 2  https://local.theonion.com/mom-starting-to-fea...
# 3  https://politics.theonion.com/boehner-just-wan...
# 4  https://www.huffingtonpost.com/entry/jk-rowlin...
#
#                                             headline  is_sarcastic
# 0  former versace store clerk sues over secret 'b...             0
# 1  the 'roseanne' revival catches up to our thorn...             0
# 2  mom starting to fear son's web series closest ...             1
# 3  boehner just wants wife to listen, not come up...             1
# 4  j.k. rowling wishes snape happy birthday in th...             0

# %%
vocab_size = 20000
embedding_dim = 200
max_length = 120
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_size = 20000

# %%
sentences = df['headline']
labels = df['is_sarcastic']
urls = df['article_link']

training_sentences = sentences[0:training_size]
testing_sentences = sentences[training_size:]
training_labels = labels[0:training_size]
testing_labels = labels[training_size:]

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)

word_index = tokenizer.word_index

training_sequences = tokenizer.texts_to_sequences(training_sentences)
training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# model = tf.keras.Sequential([
#     tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
#     tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True)),
#     tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64)),
#     tf.keras.layers.Dense(64, activation='relu'),
#     tf.keras.layers.Dense(32, activation='relu'),
#     tf.keras.layers.Dense(1, activation='sigmoid')
# ])

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()

num_epochs = 30
training_padded = np.array(training_padded)
training_labels = np.array(training_labels)
testing_padded = np.array(testing_padded)
testing_labels = np.array(testing_labels)
history = model.fit(training_padded, training_labels, epochs=num_epochs, validation_data=(testing_padded, testing_labels), verbose=1)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 120, 200)          4000000
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 200)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 24)                4824
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 4,004,849
# Trainable params: 4,004,849
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 625/625 [==============================] - 47s 75ms/step - loss: 0.6582 - accuracy: 0.5845 - val_loss: 0.4891 - val_accuracy: 0.7857
# Epoch 2/30
# 625/625 [==============================] - 46s 74ms/step - loss: 0.4163 - accuracy: 0.8595 - val_loss: 0.3568 - val_accuracy: 0.8486
# Epoch 3/30
# 625/625 [==============================] - 47s 75ms/step - loss: 0.2391 - accuracy: 0.9122 - val_loss: 0.3463 - val_accuracy: 0.8560
# Epoch 4/30
# 625/625 [==============================] - 47s 75ms/step - loss: 0.1667 - accuracy: 0.9428 - val_loss: 0.3655 - val_accuracy: 0.8571
# Epoch 5/30
# 625/625 [==============================] - 47s 76ms/step - loss: 0.1245 - accuracy: 0.9618 - val_loss: 0.4162 - val_accuracy: 0.8445
# Epoch 6/30
# 625/625 [==============================] - 49s 78ms/step - loss: 0.0892 - accuracy: 0.9716 - val_loss: 0.4311 - val_accuracy: 0.8486
# Epoch 7/30
# 625/625 [==============================] - 47s 75ms/step - loss: 0.0683 - accuracy: 0.9804 - val_loss: 0.4750 - val_accuracy: 0.8399
# Epoch 8/30
# 625/625 [==============================] - 47s 76ms/step - loss: 0.0612 - accuracy: 0.9825 - val_loss: 0.5255 - val_accuracy: 0.8416
# Epoch 9/30
# 625/625 [==============================] - 48s 77ms/step - loss: 0.0446 - accuracy: 0.9889 - val_loss: 0.5734 - val_accuracy: 0.8381
# Epoch 10/30
# 625/625 [==============================] - 48s 77ms/step - loss: 0.0342 - accuracy: 0.9931 - val_loss: 0.6439 - val_accuracy: 0.8343
# Epoch 11/30
# 625/625 [==============================] - 48s 76ms/step - loss: 0.0295 - accuracy: 0.9944 - val_loss: 0.7036 - val_accuracy: 0.8313
# Epoch 12/30
# 625/625 [==============================] - 47s 75ms/step - loss: 0.0236 - accuracy: 0.9949 - val_loss: 0.7416 - val_accuracy: 0.8293
# Epoch 13/30
# 625/625 [==============================] - 41s 66ms/step - loss: 0.0183 - accuracy: 0.9965 - val_loss: 0.8237 - val_accuracy: 0.8286
# Epoch 14/30
# 625/625 [==============================] - 40s 65ms/step - loss: 0.0171 - accuracy: 0.9972 - val_loss: 0.8325 - val_accuracy: 0.8278oss: 0.0171 - accuracy: 0.99 - ETA: 0s - loss: 0.017
# Epoch 15/30
# 625/625 [==============================] - 41s 65ms/step - loss: 0.0149 - accuracy: 0.9973 - val_loss: 0.9010 - val_accuracy: 0.8237
# Epoch 16/30
# 625/625 [==============================] - 40s 65ms/step - loss: 0.0128 - accuracy: 0.9979 - val_loss: 0.9516 - val_accuracy: 0.8210
# Epoch 17/30
# 625/625 [==============================] - 41s 65ms/step - loss: 0.0148 - accuracy: 0.9963 - val_loss: 1.0147 - val_accuracy: 0.8232
# Epoch 18/30
# 625/625 [==============================] - 41s 66ms/step - loss: 0.0119 - accuracy: 0.9978 - val_loss: 1.0269 - val_accuracy: 0.8219
# Epoch 19/30
# 625/625 [==============================] - 41s 66ms/step - loss: 0.0084 - accuracy: 0.9987 - val_loss: 1.1229 - val_accuracy: 0.8222
# Epoch 20/30
# 625/625 [==============================] - 41s 66ms/step - loss: 0.0076 - accuracy: 0.9987 - val_loss: 1.1183 - val_accuracy: 0.8201
# Epoch 21/30
# 625/625 [==============================] - 42s 67ms/step - loss: 0.0067 - accuracy: 0.9989 - val_loss: 1.3176 - val_accuracy: 0.8223
# Epoch 22/30
# 625/625 [==============================] - 42s 68ms/step - loss: 0.0077 - accuracy: 0.9983 - val_loss: 1.1823 - val_accuracy: 0.8202
# Epoch 23/30
# 625/625 [==============================] - 42s 66ms/step - loss: 0.0065 - accuracy: 0.9987 - val_loss: 1.5001 - val_accuracy: 0.8186
# Epoch 24/30
# 625/625 [==============================] - 42s 67ms/step - loss: 0.0107 - accuracy: 0.9972 - val_loss: 1.3432 - val_accuracy: 0.8211
# Epoch 25/30
# 625/625 [==============================] - 43s 69ms/step - loss: 0.0049 - accuracy: 0.9990 - val_loss: 1.2573 - val_accuracy: 0.8149
# Epoch 26/30
# 625/625 [==============================] - 44s 71ms/step - loss: 0.0056 - accuracy: 0.9991 - val_loss: 1.3156 - val_accuracy: 0.8192
# Epoch 27/30
# 625/625 [==============================] - 44s 70ms/step - loss: 0.0049 - accuracy: 0.9989 - val_loss: 1.4041 - val_accuracy: 0.8217
# Epoch 28/30
# 625/625 [==============================] - 43s 68ms/step - loss: 0.0033 - accuracy: 0.9993 - val_loss: 1.3340 - val_accuracy: 0.8152
# Epoch 29/30
# 625/625 [==============================] - 43s 69ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 1.4152 - val_accuracy: 0.8170
# Epoch 30/30
# 625/625 [==============================] - 43s 68ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 1.4027 - val_accuracy: 0.8007

# %%
#Inferencing
sentence1 = ["Sarcasm is like cheap wine - it leaves a terrible after taste", "game of thrones season finale showing this sunday night"]
sentence2 = ["I work 40 hours a week for me to be this poor", "Pakistan beat India in the World Cup"]
sentence3 = ["What a great rainy day to enjoy a cricket match", "The corona virus outbreak led to a pandemic"]
sentence4 = ["What a great day for Manchester United to have lost to Liverpool 5-0", "Liverpool defeated Manchester United" ]
sentence5 = ["inclement weather prevents liar from getting to work", "former versace store clerk sues over secret 'black code' for minority shoppers"]
sentence = ["Sarcasm is like cheap wine - it leaves a terrible after taste", "game of thrones season finale showing this sunday night", "I work 40 hours a week for me to be this poor", "Pakistan beat India in the World Cup", "What a great rainy day to enjoy a cricket match", "The corona virus outbreak led to a pandemic", "What a great day for Manchester United to have lost to Liverpool 5-0", "Liverpool defeated Manchester United", "inclement weather prevents liar from getting to work", "former versace store clerk sues over secret 'black code' for minority shoppers"]
#Thank you for explaining that my eye cancer isn't going to make me deaf. I feel so fortunate that an intellectual giant like yourself would deign to operate on me.
#granny starting to fear spiders in the garden might be real
threshold = 0.7
sequences = tokenizer.texts_to_sequences(sentence)
padded = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)
prediction=model.predict(padded)
prediction_rounded=np.round(prediction, decimals = 4)
# print(prediction_rounded)
# print(prediction_rounded[4])
for i in range(10):
    if prediction_rounded[i]>threshold:
     print(sentence[i]+': '+'Sarcastic')
    else:
     print(sentence[i]+': '+'Non-Sarcastic')




# predictions=[]
# for i in range(1,6):
#     sequences = tokenizer.texts_to_sequences('sentence'+str(i))
#     padded = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)
#     prediction=model.predict(padded)
#     prediction_rounded=np.round(prediction, decimals = 4)
#     #predictions.append(prediction_rounded)
# #     print('sentence'+str(i)+': ')
#     print(prediction_rounded)
#     #print('sentence'+str(i)+': '+prediction_rounded)

# #print(predictions)
# Out:
# Sarcasm is like cheap wine - it leaves a terrible after taste: Non-Sarcastic
# game of thrones season finale showing this sunday night: Non-Sarcastic
# I work 40 hours a week for me to be this poor: Sarcastic
# Pakistan beat India in the World Cup: Non-Sarcastic
# What a great rainy day to enjoy a cricket match: Sarcastic
# The corona virus outbreak led to a pandemic: Non-Sarcastic
# What a great day for Manchester United to have lost to Liverpool 5-0: Non-Sarcastic
# Liverpool defeated Manchester United: Non-Sarcastic
# inclement weather prevents liar from getting to work: Sarcastic
# former versace store clerk sues over secret 'black code' for minority shoppers: Non-Sarcastic
